# %%
from bmstestbedc2f2.systems.neural.datasets import load_datasets_v2

# %%
df = load_datasets_v2()
df
# Out:
# Feature                 power  (0, temperature)  (0, temperature_delta)  \
# Time
# 2024-09-01 00:15:00  0.015907         25.283691               -0.015879
# 2024-09-01 00:30:00  0.015913         25.288202               -0.004511
# 2024-09-01 00:45:00  0.015897         25.300575               -0.012373
# 2024-09-01 01:00:00  0.015887         25.286261                0.014315
# 2024-09-01 01:15:00  0.015863         25.286654               -0.000393
# ...                       ...               ...                     ...
# 2024-11-30 22:45:00  0.015847         23.656406               -0.022503
# 2024-11-30 23:00:00  0.015867         23.661388               -0.004982
# 2024-11-30 23:15:00  0.015869         23.688265               -0.026876
# 2024-11-30 23:30:00  0.015863         23.717361               -0.029097
# 2024-11-30 23:45:00  0.015880         23.750507               -0.033146
#
# Feature              (0, temperature_error)  (1, temperature)  \
# Time
# ...

# %%
import seaborn as sns
sns.heatmap(df.dropna().corr(), annot=False)
# Out:
# <Axes: xlabel='Feature', ylabel='Feature'>
